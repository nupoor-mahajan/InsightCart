# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/cleaned_reviews.csv")

# %%
df.head()
# Out:
#    Reviewer Name                     Profile Link Country Review Count  \
# 0           Lisa  /users/63c2d28aff751c001470ce46      US     1 review
# 1       J Ellery  /users/4f5291a30000640001153f96      GB    6 reviews
# 2  Heather Weber  /users/5d37078e6614abe3ab453adf      US     1 review
# 3       Mrs Lowe  /users/5666ab6d0000ff0001f14958      GB    2 reviews
# 4       Lolo Paz  /users/5d8732fb681610d90db66d2e      US    2 reviews
#
#                 Review Date  Rating  \
# 0  2023-01-14T18:41:59.000Z       1
# 1  2012-03-03T21:50:56.000Z       5
# 2  2019-07-23T13:12:41.000Z       3
# 3  2015-12-08T10:07:54.695Z       5
# 4  2019-09-22T08:41:50.000Z       4
#
#                                  Review Title  \
# 0  What happened to quality customer service?
# 1                             Best on the web
# 2                Issues with online purchases
# 3                         Excellent as always
# 4          Ive been shopping with amazon for…
#
#                                          Review Text  Date of Experience  \
# 0  I ordered several items on Jan 2, this review ...    January 14, 2023
# 1  Never any problems.goods always arrive when st...      March 03, 2012
# 2  Recently, I have been having issues with my or...       July 23, 2019
# 3                                         Very good.                 NaN
# 4  Ive been shopping with amazon for almost a yea...  September 22, 2019
#
#   Sentiment
# 0  Negative
# 1  Positive
# 2   Neutral
# 3  Positive
# 4  Positive

# %%
df.shape
# Out:
# (42740, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42740 entries, 0 to 42739
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Reviewer Name       42740 non-null  object
#  1   Profile Link        42740 non-null  object
#  2   Country             42737 non-null  object
#  3   Review Count        42740 non-null  object
#  4   Review Date         42740 non-null  object
#  5   Rating              42740 non-null  int64
#  6   Review Title        42740 non-null  object
#  7   Review Text         42740 non-null  object
#  8   Date of Experience  41636 non-null  object
#  9   Sentiment           42740 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.3+ MB

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    17923
# Negative    14349
# Neutral     10468
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='Sentiment',
    data=df,
    palette='viridis'
)

plt.title("Customer Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_9876\294271324.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(

# %%
plt.figure(figsize=(7,5))

sns.countplot(
    x='Rating',
    data=df
)

plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
df['Sentiment'].value_counts().plot.pie(
    autopct='%1.1f%%',
    figsize=(6,6)
)

plt.title("Sentiment Percentage")

plt.ylabel("")

plt.show()

# %%
top_countries = df['Country'].value_counts().head(10)

plt.figure(figsize=(10,5))

plt.fill_between(
    top_countries.index,
    top_countries.values,
    alpha=0.5
)

plt.plot(
    top_countries.index,
    top_countries.values,
    marker='o'
)

plt.title("Top 10 Countries by Reviews")
plt.xlabel("Country")
plt.ylabel("Number of Reviews")
plt.grid(True)

plt.show()

# %%
df.to_csv(
    "../data/eda_reviews.csv",
    index=False
)
